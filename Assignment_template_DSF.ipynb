# %% [markdown]
# ### Arahan Assignment
# 0. Gunakan dataset student score
# 1. Lakukan proses Exploratory data analysis
# 2. Lakukan feature engineering :
# - Check Duplicated Data
# - Check Missing Value Handling
# - Outlier Analysis
# 3. Lakukan modelling machine learning regression : gunakan minimal 2 model (linear regression, decision tree regressor, atau random forest regressor)
# 4. Lakukan evaluasi model
# 5. Berikan kesimpulan model mana yang terbaik performanya

# %% [markdown]
# #### *Supervised - Salary Prediction - Regression*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# #### Import dataset

# %%
# Read dataset using pandas
dataset = pd.read_csv('student_scores.csv')

# Displans the first five rows of the dataset
dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# #### Exploratory Data Analysis

# %%
# Provides som information regarding the columns in the data
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 532.0 bytes

# %%
# This describes the basic stat behind the dataset used
dataset.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
# These plots help to explain the values and how they are scattered

plt.figure(figsize=(12,6))
sns.pairplot(dataset, x_vars=['Hours'], y_vars=['Scores'], size=7, kind='scatter')
plt.xlabel('Hours')
plt.ylabel('Score')
plt.title('Score Prediction')
plt.show()
# Out:
# C:\Users\Gregorius Christian\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# #### Feature Engineering
# 1. Check Duplicated Data
# 2. Check Missing Value Handling
# 3. Outlier Analysis
# 4. Encoding categorical: change string (categorical) into numerical -> in this dataset, there are no categorical data.

# %% [markdown]
# #### Investigate of Feature Engineering

# %%
df = dataset.copy()

# %%
# Check Dulplicated Data
print("Data Sebelum Pemeriksaan Duplikat: ")
print(df.shape)
# Out:
# Data Sebelum Pemeriksaan Duplikat:
# (25, 2)

# %%
duplicated_rows_before = df[df.duplicated()]
duplicated_rows_before
# Out:
# Empty DataFrame
# Columns: [Hours, Scores]
# Index: []

# %%
df = df.drop_duplicates()

# %%
print("\nData Setelah Pemeriksaan Duplikat: ")
print(df.shape)
# Out:
# Data Setelah Pemeriksaan Duplikat:
# (25, 2)

# %%
# Check missing value
df.isna().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %% [markdown]
# There is no missing value

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Outlier Analysis
sns.boxplot(x="Hours", data=df)

# Menambahkan label sumbu dan judul
plt.xlabel("Hours")
plt.ylabel("Score")
plt.title("Boxplot Hours")

# Menampilkan plot
plt.show()

# %%
# Hours
print("\n")
X = df['Hours']
X.head()
# Out:
# 0    2.5
# 1    5.1
# 2    3.2
# 3    8.5
# 4    3.5
# Name: Hours, dtype: float64

# %%
# Score data
y = df['Scores']
y.head()
# Out:
# 0    21
# 1    47
# 2    27
# 3    75
# 4    30
# Name: Scores, dtype: int64

# %%
# Import machine learning data form scikit learn
from sklearn.model_selection import train_test_split
